# %% [markdown]
# ### **CRAWLING TWITTER USING API**

# %%
# !pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tweepy
import pandas as pd
import numpy as np


access_token = "xxxxx"
access_token_secret = "xxxxx"
API_key = "xxxxx"
API_secret = "xxxxx"


auth = tweepy.OAuthHandler(API_key, API_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

tweets = api.search_tweets("seventeen", count=500, lang="id")

# %%
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f57eb21fac0>, _json={'created_at': 'Thu Mar 30 14:17:19 +0000 2023', 'id': 1641444497073786880, 'id_str': '1641444497073786880', 'text': '/aj yuk yang mau ikut P0 SEVENTEEN LOVE JAPAN FANMEET MERCH bisa di kita ^^. DOM JATIM. dm @TokkiJantan\nhttps://t.co/tFSEGWsqP4', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TokkiJantan', 'name': '🐰Om Tojan || WH JP RATE 130 🇯🇵 || WH KR🇰🇷', 'id': 1132266418831892481, 'id_str': '1132266418831892481', 'indices': [91, 103]}], 'urls': [{'url': 'https://t.co/tFSEGWsqP4', 'expanded_url': 'https://twitter.com/TokkiJantan/status/1640928247839092736?t=O61YnztBduUjmB7_JKkncQ&s=19', 'display_url': 'twitter.com/TokkiJantan/st…', 'indices': [104, 127]}]}, 'metadata': {'iso_language_code': 'in', 'result_type': 'recent'}, 'source': '<a href="https://twitter.com/bimmenfess" rel="nofollow">borahae</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 
# ...

# %%
# Print the collected tweet
data = pd.DataFrame()
data["Created At"] = [tweet.created_at for tweet in tweets]
data["Screen Name"] = [tweet.user.screen_name for tweet in tweets]
data["Tweet"] = [tweet.text for tweet in tweets]
data["Location"] = [tweet.user.location for tweet in tweets]
data["Number of Retweet"] = [tweet.retweet_count for tweet in tweets]
data['Number of Like'] = [tweet.favorite_count for tweet in tweets]
display(data.head(500))
# Out:
#                   Created At      Screen Name  \
# 0  2023-03-30 14:17:19+00:00       KantinHYBE
# 1  2023-03-30 14:17:03+00:00       cloudshu3_
# 2  2023-03-30 14:16:53+00:00     beru_bea_alt
# 3  2023-03-30 14:16:51+00:00        waifuwonu
# 4  2023-03-30 14:16:34+00:00      aiurs_skies
# ..                       ...              ...
# 95 2023-03-30 13:49:49+00:00       clumsygyuu
# 96 2023-03-30 13:49:05+00:00        kwonsrawr
# 97 2023-03-30 13:48:50+00:00          Ceszy19
# 98 2023-03-30 13:48:40+00:00  igranstvutamaid
# 99 2023-03-30 13:48:07+00:00          nashuji
#
#                                                 Tweet                Location  \
# 0   /aj yuk yang mau ikut P0 SEVENTEEN LOVE JAPAN ...          BACA RULES  ➡️
# 1   @boysplanetarea Lah iya juga😭 udah terdeteksi ...          akun suka suka
# 2   RT @caratstalk: [17s] udah balik kayak dulu la...
# 3   RT @caratstalk: [17s] guys coba drop video edi...             chweranghae
# ...

# %%
# Save as .CSV
data.to_csv("seventeen.csv")
